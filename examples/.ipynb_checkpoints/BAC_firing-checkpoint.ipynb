# %%
import neat
import os

# %%
#os.system('compilechannels nest models/channels/channels_hay.py --name bac_firing --nestmlresource bac_firing_syns.nestml')

# %% [raw]
# neuron bac_firing:
#
# parameters:
#     tau_r_PSC real = 0.5 ms
#     tau_d_PSC real = 5. ms
#     PSC_amp real = .5 nA
#
#
#     # parameters Ca_HVA
#     gbar_Ca_HVA real = 0.00
#     e_Ca_HVA real = 50.00
#
#     # parameters Ca_LVA
#     gbar_Ca_LVA real = 0.00
#     e_Ca_LVA real = 50.00
#
#     # parameters Kpst
#     gbar_Kpst real = 0.00
#     e_Kpst real = -85.00
#
#     # parameters Ktst
#     gbar_Ktst real = 0.00
#     e_Ktst real = -85.00
#
#     # parameters Kv3_1
#     gbar_Kv3_1 real = 0.00
#     e_Kv3_1 real = -85.00
#
#     # parameters Na_Ta
#     gbar_Na_Ta real = 0.00
#     e_Na_Ta real = 50.00
#
#     # parameters Na_p
#     gbar_Na_p real = 0.00
#     e_Na_p real = 50.00
#
#     # parameters SK
#     gbar_SK real = 0.00
#     e_SK real = -85.00
#
#     # parameters h_HAY
#     gbar_h_HAY real = 0.00
#     e_h_HAY real = -43.00
#
#     # parameters m
#     gbar_m real = 0.00
#     e_m real = -85.00
# end
#
# state:
#     v_comp real = -75.00000000
#     # state variables Ca_HVA
#     m_Ca_HVA real = 0.00000918
#     h_Ca_HVA real = 0.69823671
#
#     # state variables Ca_LVA
#     m_Ca_LVA real = 0.00291975
#     h_Ca_LVA real = 0.08756384
#
#     # state variables Kpst
#     m_Kpst real = 0.00480475
#     h_Kpst real = 0.73105858
#
#     # state variables Ktst
#     m_Ktst real = 0.03164396
#     h_Ktst real = 0.47502081
#
#     # state variables Kv3_1
#     m_Kv3_1 real = 0.00006379
#
#     # state variables Na_Ta
#     m_Na_Ta real = 0.00307019
#     h_Na_Ta real = 0.81757448
#
#     # state variables Na_p
#     m_Na_p real = 0.00761822
#     h_Na_p real = 0.93213771
#
#     # state variables SK
#     z_SK real = 0.00090982
#
#     # state variables h_HAY
#     m_h_HAY real = 0.03023216
#
#     # state variables m
#     m_m real = 0.00033535
# end
#
# equations:
#
#
#     kernel g_PSC = g_norm_PSC * ( - exp(-t / tau_r_PSC) + exp(-t / tau_d_PSC) )
#     inline PSC real = convolve(g_PSC, spikes_PSC)
#
#
#
#     # equation Ca_HVA
#     inline Ca_HVA real = gbar_Ca_HVA * (h_Ca_HVA*m_Ca_HVA**2) * (e_Ca_HVA - v_comp)
#
#     # equation Ca_LVA
#     inline Ca_LVA real = gbar_Ca_LVA * (h_Ca_LVA*m_Ca_LVA**2) * (e_Ca_LVA - v_comp)
#
#     # equation Kpst
#     inline Kpst real = gbar_Kpst * (h_Kpst*m_Kpst**2) * (e_Kpst - v_comp)
#
#     # equation Ktst
#     inline Ktst real = gbar_Ktst * (h_Ktst*m_Ktst**2) * (e_Ktst - v_comp)
#
#     # equation Kv3_1
#     inline Kv3_1 real = gbar_Kv3_1 * (m_Kv3_1) * (e_Kv3_1 - v_comp)
#
#     # equation Na_Ta
#     inline Na_Ta real = gbar_Na_Ta * (h_Na_Ta*m_Na_Ta**3) * (e_Na_Ta - v_comp)
#
#     # equation Na_p
#     inline Na_p real = gbar_Na_p * (h_Na_p*m_Na_p**3) * (e_Na_p - v_comp)
#
#     # equation SK
#     inline SK real = gbar_SK * (z_SK) * (e_SK - v_comp)
#
#     # equation h_HAY
#     inline h_HAY real = gbar_h_HAY * (m_h_HAY) * (e_h_HAY - v_comp)
#
#     # equation m
#     inline m real = gbar_m * (m_m) * (e_m - v_comp)
# end
#
#
#
# # functions Ca_HVA
# function m_inf_Ca_HVA (v_comp real) real:
#     return -0.055*(-0.055*(27.0 + v_comp)*(-1.0 + exp(0.263157894736842*(-27.0 - v_comp)))**(-1) + 0.94*exp(0.0588235294117647*(-75.0 - v_comp)))**(-1)*(-1.0 + exp(0.263157894736842*(-27.0 - v_comp)))**(-1)*(27.0 + v_comp)
# end
# function tau_m_Ca_HVA (v_comp real) real:
#     return 1.0*(-0.055*(27.0 + v_comp)*(-1.0 + exp(0.263157894736842*(-27.0 - v_comp)))**(-1) + 0.94*exp(0.0588235294117647*(-75.0 - v_comp)))**(-1)
# end
# function h_inf_Ca_HVA (v_comp real) real:
#     return 0.000457*(0.0065*(1.0 + exp(0.0357142857142857*(-15.0 - v_comp)))**(-1) + 0.000457*exp(0.02*(-13.0 - v_comp)))**(-1)*exp(0.02*(-13.0 - v_comp))
# end
# function tau_h_Ca_HVA (v_comp real) real:
#     return 1.0*(0.0065*(1.0 + exp(0.0357142857142857*(-15.0 - v_comp)))**(-1) + 0.000457*exp(0.02*(-13.0 - v_comp)))**(-1)
# end
#
# # functions Ca_LVA
# function m_inf_Ca_LVA (v_comp real) real:
#     return 1.0*(1.0 + exp(0.166666666666667*(-40.0 - v_comp)))**(-1)
# end
# function tau_m_Ca_LVA (v_comp real) real:
#     return 5.0 + 6.77966101694915*(1.0 + exp(0.2*(35.0 + v_comp)))**(-1)
# end
# function h_inf_Ca_LVA (v_comp real) real:
#     return 1.0*(1.0 + exp(0.15625*(90.0 + v_comp)))**(-1)
# end
# function tau_h_Ca_LVA (v_comp real) real:
#     return 20.0 + 16.9491525423729*(1.0 + exp(0.142857142857143*(50.0 + v_comp)))**(-1)
# end
#
# # functions Kpst
# function m_inf_Kpst (v_comp real) real:
#     return 1.0*(1.0 + exp(0.0833333333333333*(-11.0 - v_comp)))**(-1)
# end
# function tau_m_Kpst (v_comp real) real:
#     return 1.03050847457627 + 5.86440677966102*exp(-14.2399430402278*(1 + 0.0166666666666667*v_comp)**2) + 8.54237288135593*exp(-1.09264407726208*(1 + 0.0166666666666667*v_comp)**2)
# end
# function h_inf_Kpst (v_comp real) real:
#     return 1.0*(1.0 + exp(0.0909090909090909*(64.0 + v_comp)))**(-1)
# end
# function tau_h_Kpst (v_comp real) real:
#     return 122.033898305085 + 0.338983050847458*(1010.0 + 24.0*(65.0 + v_comp))*exp(-3.13585069444444*(1 + 0.0117647058823529*v_comp)**2)
# end
#
# # functions Ktst
# function m_inf_Ktst (v_comp real) real:
#     return 1.0*(1.0 + exp(0.0526315789473684*(-10.0 - v_comp)))**(-1)
# end
# function tau_m_Ktst (v_comp real) real:
#     return 0.115254237288136 + 0.311864406779661*exp(-1.88480321746625*(1 + 0.0123456790123457*v_comp)**2)
# end
# function h_inf_Ktst (v_comp real) real:
#     return 1.0*(1.0 + exp(0.1*(76.0 + v_comp)))**(-1)
# end
# function tau_h_Ktst (v_comp real) real:
#     return 2.71186440677966 + 16.6101694915254*exp(-13.0226843100189*(1 + 0.0120481927710843*v_comp)**2)
# end
#
# # functions Kv3_1
# function m_inf_Kv3_1 (v_comp real) real:
#     return 1.0*(1.0 + exp(0.103092783505155*(18.7 - v_comp)))**(-1)
# end
# function tau_m_Kv3_1 (v_comp real) real:
#     return 4.0*(1.0 + exp(0.0226551880380607*(-46.56 - v_comp)))**(-1)
# end
#
# # functions Na_Ta
# function m_inf_Na_Ta (v_comp real) real:
#     return 0.182*(1.0 - exp(0.166666666666667*(-38.0 - v_comp)))**(-1)*(0.182*(38.0 + v_comp)*(1.0 - exp(0.166666666666667*(-38.0 - v_comp)))**(-1) - 0.124*(38.0 + v_comp)*(1.0 - exp(0.166666666666667*(38.0 + v_comp)))**(-1))**(-1)*(38.0 + v_comp)
# end
# function tau_m_Na_Ta (v_comp real) real:
#     return 0.338983050847458*(0.182*(38.0 + v_comp)*(1.0 - exp(0.166666666666667*(-38.0 - v_comp)))**(-1) - 0.124*(38.0 + v_comp)*(1.0 - exp(0.166666666666667*(38.0 + v_comp)))**(-1))**(-1)
# end
# function h_inf_Na_Ta (v_comp real) real:
#     return -0.015*(1.0 - exp(0.166666666666667*(66.0 + v_comp)))**(-1)*(0.015*(66.0 + v_comp)*(1.0 - exp(0.166666666666667*(-66.0 - v_comp)))**(-1) - 0.015*(66.0 + v_comp)*(1.0 - exp(0.166666666666667*(66.0 + v_comp)))**(-1))**(-1)*(66.0 + v_comp)
# end
# function tau_h_Na_Ta (v_comp real) real:
#     return 0.338983050847458*(0.015*(66.0 + v_comp)*(1.0 - exp(0.166666666666667*(-66.0 - v_comp)))**(-1) - 0.015*(66.0 + v_comp)*(1.0 - exp(0.166666666666667*(66.0 + v_comp)))**(-1))**(-1)
# end
#
# # functions Na_p
# function m_inf_Na_p (v_comp real) real:
#     return 1.0*(1.0 + exp(0.217391304347826*(-52.6 - v_comp)))**(-1)
# end
# function tau_m_Na_p (v_comp real) real:
#     return 2.03389830508475*((1.0 - 0.00177610354573438*exp(-0.166666666666667*v_comp))**(-1)*(6.916 + 0.182*v_comp) + (1.0 - 563.030236835951*exp(0.166666666666667*v_comp))**(-1)*(-4.712 - 0.124*v_comp))**(-1)
# end
# function h_inf_Na_p (v_comp real) real:
#     return 1.0*(1.0 + exp(0.1*(48.8 + v_comp)))**(-1)
# end
# function tau_h_Na_p (v_comp real) real:
#     return 0.338983050847458*((1.0 - 2.32041026342014e-11*exp(-0.380228136882129*v_comp))**(-1)*(0.000446936 + 6.94e-6*v_comp) + (1.0 - 39.3189371247744*exp(0.215982721382289*v_comp))**(-1)*(-4.896e-5 - 2.88e-6*v_comp))**(-1)
# end
#
# # functions SK
# function z_inf_SK (v_comp real) real:
#     return 0.000909821306333216
# end
# function tau_z_SK (v_comp real) real:
#     return 1.00000000000000
# end
#
# # functions h_HAY
# function m_inf_h_HAY (v_comp real) real:
#     return 0.00643*(0.00643*(154.9 + v_comp)*(-1.0 + exp(0.0840336134453781*(154.9 + v_comp)))**(-1) + 0.193*exp(0.0302114803625378*v_comp))**(-1)*(-1.0 + exp(0.0840336134453781*(154.9 + v_comp)))**(-1)*(154.9 + v_comp)
# end
# function tau_m_h_HAY (v_comp real) real:
#     return 1.0*(0.00643*(154.9 + v_comp)*(-1.0 + exp(0.0840336134453781*(154.9 + v_comp)))**(-1) + 0.193*exp(0.0302114803625378*v_comp))**(-1)
# end
#
# # functions m
# function m_inf_m (v_comp real) real:
#     return 0.109280991463685*(9.96513652936511e-5*exp(-0.1*v_comp) + 0.109280991463685*exp(0.1*v_comp))**(-1)*exp(0.1*v_comp)
# end
# function tau_m_m (v_comp real) real:
#     return 0.338983050847458*(9.96513652936511e-5*exp(-0.1*v_comp) + 0.109280991463685*exp(0.1*v_comp))**(-1)
# end
#
# internals:
#     tp_PSC real = (tau_r_PSC * tau_d_PSC) / (tau_d_PSC - tau_r_PSC) * ln( tau_d_PSC / tau_r_PSC )
#     g_norm_PSC real =  PSC_amp / ( -exp( -tp_PSC / tau_r_PSC ) + exp( -tp_PSC / tau_d_PSC ) )
# end
#
# input:
#     spikes_PSC uS <- spike
# end
#
#
#
# end

# %%
import numpy as np
import nest

from neat import createNestModel

import pickle

from models.L5_pyramid import getL5Pyramid
from plotutil import *

"""
compilechannels nest models/channels/channels_hay.py --name bac_firing --nestmlresource bac_firing_syns.nestml
"""
nest.Install("bac_firing_neatmodule")


def runCaCoinc(c_tree,
               ca_loc_idx, soma_ind,
               stim_type='psp',
               dt=0.05, t_max=300., t_calibrate=400.,
               psp_params=dict(tau_r_PSC=.5, tau_d_PSC=5., PSC_amp=.5, t_PSC=50.),
               i_in_params=dict(i_amp=1.9, t_onset=45., t_dur=5.),
               rec_kwargs=dict(record_from_syns=False, record_from_iclamps=False,
                               record_from_vclamps=False, record_from_channels=False,
                               record_v_deriv=False),
               pprint=True):
    """
    Runs the BAC-firing protocol to elicit an AP burst in response to coincident
    somatic and dendritic input
    """
    idx_calibrate = int(t_calibrate / dt)

    nest.ResetKernel()
    nest.SetKernelStatus(dict(resolution=dt, min_delay=dt, max_delay=1.5))

    # initialize the NEST model
    cm = createNestModel(c_tree, 'bac_firing')

    if stim_type == 'psp' or stim_type == 'coinc':
        syn_idx = nest.AddReceptor(cm, ca_loc_idx, "PSC", psp_params)
        sg_psc = nest.Create('spike_generator', 1, {'spike_times': [psp_params['t_PSC']+t_calibrate]})
        nest.Connect(sg_psc, cm, syn_spec={
            'synapse_model': 'static_synapse', 'weight': 1., 'delay': 0.1, 'receptor_type': syn_idx})

    if stim_type == 'current' or stim_type == 'coinc':
        dcg = nest.Create('dc_generator', {"amplitude": i_in_params['i_amp'],
                                           "start": i_in_params['t_onset']+t_calibrate,
                                           "stop": i_in_params['t_onset']+i_in_params['t_dur']+t_calibrate})
        nest.Connect(dcg, cm, syn_spec={
                    'synapse_model': 'static_synapse', 'weight': 1., 'delay': 2.*dt, 'receptor_type': soma_ind})

    mm = nest.Create('multimeter', 1, {'record_from': ['V_m_%d'%node.index for node in c_tree], 'interval': dt})
    nest.Connect(mm, cm)

    # simulate the NEST model
    nest.Simulate(t_max+t_calibrate)
    res = nest.GetStatus(mm, 'events')[0]

    for key in res:
        res[key] = res[key][idx_calibrate:]
        if key == 'times':
            res[key] -= res[key][0]

    return res


def runCalciumCoinc(dt=0.05):
    import bac_firing

    lss_ = ['-', '-.', '--']
    css_ = [colours[3], colours[0], colours[1]]
    lws_ = [.8, 1.2, 1.6]
    pl.figure('V trace', figsize=(6,8))
    gs = GridSpec(2,2)
    gs.update(top=.9, bottom=.2, left=.3, right=.9, hspace=.05, wspace=.1)
    axes_trace = [pl.subplot(gs[0,0]), pl.subplot(gs[0,1]), pl.subplot(gs[1,:])]
    vd_offset = 7.2
    vlim = (-80.,20.)

    # create the full model
    phys_tree = getL5Pyramid()

    # single branch initiation zone
    branch = phys_tree.path_to_root(phys_tree[236])[::-1]
    locs_sb = phys_tree.distribute_locs_at_d2s(bac_firing.D2S_CASPIKE, node_arg=branch, name='single branch')
    # abpical trunk locations
    apic = phys_tree.path_to_root(phys_tree[221])[::-1]
    locs_apic = phys_tree.distribute_locs_at_d2s(bac_firing.D2S_APIC, node_arg=apic, name='apic connection')

    # store set of locations
    fit_locs = [(1, .5)] + locs_apic + locs_sb
    phys_tree.store_locs(fit_locs, name='ca coinc')
    # PSP input location index
    ca_ind = phys_tree.get_nearest_loc_idxs([bac_firing.CA_LOC], name='ca coinc')[0]

    # obtain the simplified tree
    file = open('data/ctree_bac_firing.p', 'rb')
    ctree = pickle.load(file)
    clocs = pickle.load(file)
    file.close()

    for jj, stim in enumerate(['current', 'psp', 'coinc']):
        # runn the simulation
        res = runCaCoinc(ctree, ca_ind, 0, stim_type=stim, dt=dt,
                    rec_kwargs=dict(record_from_syns=True, record_from_iclamps=True))

        # somatic trace
        ax = axes_trace[jj]
        ax.set_xticks([0.,50.])
        ax.plot(res['times'], res['V_m_0'], c=cll[0], lw=1.6*lwidth)

        # dendritic trace
        ax.plot(res['times'], res['V_m_%d'%ca_ind]+vd_offset, c=cll[1], lw=1.6*lwidth)

        ax.set_yticks([res['V_m_0'][0], res['V_m_%d'%ca_ind][0]+vd_offset])
        if jj == 1 or jj == 2:
            drawScaleBars(ax, xlabel=' ms', ylabel=' mV', b_offset=15)
            # drawScaleBars(ax, xlabel=' ms', b_offset=25)
        else:
            drawScaleBars(ax)
        if jj == 2:
            ax.set_yticklabels([r'Soma', r'Dend'])
        ax.set_ylim(vlim)

runCalciumCoinc()
